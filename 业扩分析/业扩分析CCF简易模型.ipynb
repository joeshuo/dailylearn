# %%
#该代码需要已分类出高压、低压新装、增容、销户、减容数据，以及电量数据的excel文件，单位为万千伏安、万千瓦时
#该代码块对电量数据进行季节性调整后一阶差分、对业扩数据进行一阶差分
#输出文件为经过CCF分析的结果，得到滞后期数据，影响系数数据

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.seasonal import STL # 导入STL
from statsmodels.tsa.stattools import ccf
from IPython.display import display
import re

# ==============================================================================
# 0. 参数配置
# ==============================================================================
# 指向您的【原始】数据文件
FILE_PATH = r'E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月底电量报告全行业_净值.xlsx' 
# 新的输出文件名，以反映处理方法
OUTPUT_PATH = r'E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月底电量报告全行业_净值_业扩分析结果.xlsx'
SHEET_MAP = {
    'kwh': '电量',
    'cap_high_new': '高压净新装',
    'cap_high_exp': '高压净增容',
    'cap_low_new': '低压净新装',
    'cap_low_exp': '低压净增容'
}

# ==============================================================================
# 1. 数据加载与预处理函数 (封装复杂性)
# ==============================================================================
def load_and_prepare_data(file_path, sheet_map):
    """
    加载所有原始数据Sheet，进行清洗和格式转换，返回一个包含所有数据的字典。
    """
    print("--- 步骤 1: 正在加载并预处理所有原始数据 ---")
    all_data = {}
    for var_name, sheet_name in sheet_map.items():
        try:
            df = pd.read_excel(file_path, sheet_name=sheet_name)
            df['分类'] = df['分类'].astype(str).str.strip()
            valid_date_cols = [col for col in df.columns if re.match(r'^\d{6}$', str(col).split('.')[0])]
            df = df[['分类'] + valid_date_cols]
            df_long = df.melt(id_vars='分类', var_name='date', value_name=var_name)
            df_long['date'] = pd.to_datetime(df_long['date'].astype(str), format='%Y%m')
            df_long[var_name] = pd.to_numeric(df_long[var_name], errors='coerce').fillna(0)
            all_data[var_name] = df_long.set_index(['分类', 'date'])
            print(f"  -> Sheet '{sheet_name}' 加载并转换成功。")
        except Exception as e:
            raise RuntimeError(f"处理Sheet '{sheet_name}' 时出错: {e}")
    
    df_full = pd.concat(all_data.values(), axis=1)
    return df_full

# ==============================================================================
# 2. 主分析流程
# ==============================================================================
def run_full_analysis(df_full):
    """
    对加载好的完整数据，分行业进行 预处理 -> CCF -> 回归建模 的完整流程。
    """
    print("\n--- 步骤 2: 开始分行业进行完整分析流程 ---")
    
    industry_list = df_full.index.get_level_values('分类').unique().tolist()
    print(f"将对以下 {len(industry_list)} 个行业进行分析。")
    
    final_results = []

    for industry in industry_list:
        print(f"\n{'='*25} 正在分析: {industry} {'='*25}")
        
        df_industry_raw = df_full.loc[industry]
        
        # --- B. 序列平稳化 (STL + 差分版) ---
        df_processed = pd.DataFrame()
        
        # ★★★★★★★★★★★ 关键修改点 ★★★★★★★★★★★
        # 对电量数据进行STL季节性调整后，再进行一阶差分
        kwh_ts = df_industry_raw['kwh']
        try:
            # 检查数据是否适合进行STL分解
            if len(kwh_ts.dropna()) < 25 or kwh_ts.std() < 1e-6:
                print("    -> 电量数据不足或无波动，仅进行一阶差分。")
                df_processed['d_kwh'] = kwh_ts.diff(1)
            else:
                print("    -> 正在对电量数据进行STL季节性调整...")
                stl = STL(kwh_ts, period=12, robust=True)
                res = stl.fit()
                kwh_seasonally_adjusted = res.trend + res.resid
                df_processed['d_kwh'] = kwh_seasonally_adjusted.diff(1)
                print("    -> STL调整并一阶差分完成。")
                
        except Exception as e:
            print(f"    -> 警告: STL处理失败 ({e})，回退到仅进行一阶差分。")
            df_processed['d_kwh'] = kwh_ts.diff(1)
        # ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★

        # 对业扩数据进行一阶差分
        for cap_var in [c for c in df_industry_raw.columns if c != 'kwh']:
            df_processed[cap_var] = df_industry_raw[cap_var].diff(1)
        
        df_processed.dropna(inplace=True)
        
        if len(df_processed) < 30:
            print("    -> 预处理后数据点不足 (< 30)，跳过。")
            continue
        print(f"    -> 数据平稳化完成，剩余 {len(df_processed)} 个有效数据点。")
        
        # --- C. CCF分析确定滞后期 ---
        lags = {}
        exog_vars = [c for c in df_processed.columns if c != 'd_kwh']
        for var in exog_vars:
            ccf_vals = ccf(df_processed['d_kwh'], df_processed[var], adjusted=False)
            relevant_lags = range(1, 9)
            best_lag = relevant_lags[np.argmax(np.abs(ccf_vals[1:9]))]
            lags[var] = best_lag
        print(f"    -> CCF分析完成，最佳滞后期: {lags}")

        # --- D. 回归建模 ---
        df_model = df_processed[['d_kwh']].copy()
        for var, lag in lags.items():
            df_model[f'{var}_lag{lag}'] = df_processed[var].shift(lag)
        df_model.dropna(inplace=True)
        
        if len(df_model) < 25:
            print("    -> 创建滞后变量后数据点不足 (< 25)，跳过。")
            continue
            
        Y = df_model['d_kwh']
        X = df_model.drop(columns='d_kwh')
        X = sm.add_constant(X)
        model_results = sm.OLS(Y, X).fit()
        
        # --- E. 提取结果 ---
        result_row = {'行业分类': industry, 'R-squared_adj': model_results.rsquared_adj}
        for var, lag in lags.items():
            result_row[f'k_{var}'] = lag
            param_name = f'{var}_lag{lag}'
            result_row[f'β_{var}'] = model_results.params.get(param_name, np.nan)
            result_row[f'p_{var}'] = model_results.pvalues.get(param_name, np.nan)
        
        final_results.append(result_row)
        print(f"    -> 回归建模完成，调整后R²: {model_results.rsquared_adj:.3f}")

    return pd.DataFrame(final_results)

# ==============================================================================
# 3. 结果展示与保存
# ==============================================================================
def display_and_save_results(df_summary, output_path):
    if df_summary.empty:
        print("\n未能完成任何行业的分析。")
        return

    print(f"\n{'='*30} 所有行业分析结果汇总 {'='*30}")
    df_summary.set_index('行业分类', inplace=True)

    lag_cols = sorted([c for c in df_summary.columns if c.startswith('k_')])
    df_lags = df_summary[lag_cols].rename(columns=lambda c: c.replace('k_', ''))
    print("\n各行业【最佳影响滞后期(月)】汇总:")
    display(df_lags)
    
    beta_cols = sorted([c for c in df_summary.columns if c.startswith('β_')])
    df_betas = df_summary[beta_cols].rename(columns=lambda c: c.replace('β_', ''))
    print("\n各行业【影响系数(β值 - kWh/kVA)】汇总 (绿色粗体表示统计显著):")
    
    def highlight_significant(x):
        styles = pd.DataFrame('', index=x.index, columns=x.columns)
        for beta_col in x.columns:
            pval_col = 'p_' + beta_col
            if pval_col in df_summary.columns:
                styles[beta_col] = np.where(df_summary[pval_col] < 0.1, 
                                            'font-weight: bold; color: green;', 
                                            'color: grey;')
        return styles

    styled_betas = df_betas.style.format("{:.2f}").apply(highlight_significant, axis=None)
    display(styled_betas)
    
    with pd.ExcelWriter(output_path) as writer:
        df_lags.to_excel(writer, sheet_name='滞后期(k)汇总')
        df_betas.to_excel(writer, sheet_name='影响系数(β)汇总')
        df_summary.to_excel(writer, sheet_name='全部详细结果')
    print(f"\n完整汇总结果已保存到: {output_path}")

# ==============================================================================
# 4. 执行主程序
# ==============================================================================
if __name__ == '__main__':
    # 步骤1: 加载和准备数据
    full_data = load_and_prepare_data(FILE_PATH, SHEET_MAP)
    
    # 步骤2: 运行完整分析流程
    summary_results = run_full_analysis(full_data)
    
    # 步骤3: 展示并保存结果
    display_and_save_results(summary_results, OUTPUT_PATH)

    print("\n--- 全部分析任务完成 ---")
# Out:
# --- 步骤 1: 正在加载并预处理所有原始数据 ---
#   -> Sheet '电量' 加载并转换成功。
#   -> Sheet '高压净新装' 加载并转换成功。
#   -> Sheet '高压净增容' 加载并转换成功。
#   -> Sheet '低压净新装' 加载并转换成功。
#   -> Sheet '低压净增容' 加载并转换成功。
#
# --- 步骤 2: 开始分行业进行完整分析流程 ---
# 将对以下 133 个行业进行分析。
#
# ========================= 正在分析: 全行业总计 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 5, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.357
#
# ========================= 正在分析: A、全行业用电合计 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 8, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.233
#
# ========================= 正在分析: 第一产业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 8, 'cap_low_new': 3, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.105
#
# ========================= 正在分析: 第二产业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 3, 'cap_low_new': 6, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.416
#
# ========================= 正在分析: 第三产业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 3, 'cap_low_new': 1, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.198
#
# ========================= 正在分析: B、城乡居民生活用电合计 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 8, 'cap_low_new': 8, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.245
#
# ========================= 正在分析: 城镇居民 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 8, 'cap_low_new': 8, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.385
#
# ========================= 正在分析: 乡村居民 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 3, 'cap_low_new': 2, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.305
#
# ========================= 正在分析: 全行业用电分类 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 8, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.233
#
# ========================= 正在分析: 一、农、林、牧、渔业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.143
#
# ========================= 正在分析: 1.农业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 7, 'cap_low_new': 4, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.189
#
# ========================= 正在分析: 2.林业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 4, 'cap_low_new': 4, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.054
#
# ========================= 正在分析: 3.畜牧业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 5, 'cap_low_new': 5, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.135
#
# ========================= 正在分析: 4.渔业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 6, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.756
#
# ========================= 正在分析: 5.农、林、牧、渔专业及辅助性活动 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 2, 'cap_low_new': 4, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.039
#
# ========================= 正在分析: 其中：排灌 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 2, 'cap_low_new': 7, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.145
#
# ========================= 正在分析: 二、工业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 3, 'cap_low_new': 6, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.427
#
# ========================= 正在分析: （一）采矿业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 4, 'cap_low_new': 8, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.156
#
# ========================= 正在分析: 1.煤炭开采和洗选业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 7, 'cap_low_new': 2, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.135
#
# ========================= 正在分析: 2.石油和天燃气开采业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 8, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.157
#
# ========================= 正在分析: 3.黑色金属矿采选业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 6, 'cap_low_new': 8, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.546
#
# ========================= 正在分析: 4.有色金属矿采选业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 5, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.218
#
# ========================= 正在分析: 5.非金属矿采选业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 6, 'cap_low_new': 3, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.409
#
# ========================= 正在分析: 6.其他采矿业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 4, 'cap_low_new': 8, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.539
#
# ========================= 正在分析: （二）制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 8, 'cap_low_new': 2, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.203
#
# ========================= 正在分析: 1.农副食品加工业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 6, 'cap_low_new': 2, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.165
#
# ========================= 正在分析: 2.食品制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 2, 'cap_low_new': 8, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.349
#
# ========================= 正在分析: 3.酒、饮料及精制茶制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 2, 'cap_low_new': 2, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.224
#
# ========================= 正在分析: 4.烟草制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 5, 'cap_low_new': 6, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.570
#
# ========================= 正在分析: 5.纺织业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.220
#
# ========================= 正在分析: 6.纺织服装、服饰业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 6, 'cap_low_new': 8, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.421
#
# ========================= 正在分析: 7.皮革、毛皮、羽毛及其制品和制鞋业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 1, 'cap_low_new': 2, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.502
#
# ========================= 正在分析: 8.木材加工和木、竹、藤、棕、草制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 8, 'cap_low_new': 1, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.175
#
# ========================= 正在分析: 9.家具制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 2, 'cap_low_new': 1, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.250
#
# ========================= 正在分析: 10.造纸和纸制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.182
#
# ========================= 正在分析: 11.印刷和记录媒介复制业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 8, 'cap_low_new': 7, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.013
#
# ========================= 正在分析: 12.文教、工美、体育和娱乐用品制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 3, 'cap_low_new': 5, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.179
#
# ========================= 正在分析: 其中：体育用品制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 5, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.287
#
# ========================= 正在分析: 13.石油、煤炭及其他燃料加工业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 3, 'cap_low_new': 6, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.326
#
# ========================= 正在分析: 其中：煤化工 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 6, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.014
#
# ========================= 正在分析: 14.化学原料和化学制品制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 7, 'cap_low_new': 5, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.140
#
# ========================= 正在分析: 其中：氯碱 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: -0.000
#
# ========================= 正在分析: 电石 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 3, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.401
#
# ========================= 正在分析: 黄磷 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.000
#
# ========================= 正在分析: 其中：肥料制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 7, 'cap_low_new': 6, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.230
#
# ========================= 正在分析: 15.医药制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 2, 'cap_low_new': 7, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.275
#
# ========================= 正在分析: 其中：中成药生产 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 6, 'cap_low_new': 7, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.335
#
# ========================= 正在分析: 生物药品制品制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 1, 'cap_low_new': 6, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.384
#
# ========================= 正在分析: 16.化学纤维制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 6, 'cap_low_new': 7, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.117
#
# ========================= 正在分析: 17.橡胶和塑料制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 1, 'cap_low_new': 2, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.135
#
# ========================= 正在分析: 其中：橡胶制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 4, 'cap_low_new': 7, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.588
#
# ========================= 正在分析: 塑料制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 4, 'cap_low_new': 2, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.226
#
# ========================= 正在分析: 18.非金属矿物制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 3, 'cap_low_new': 1, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.209
#
# ========================= 正在分析: 其中：水泥制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 4, 'cap_low_new': 1, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.068
#
# ========================= 正在分析: 玻璃制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 1, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.101
#
# ========================= 正在分析: 陶瓷制品制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 7, 'cap_low_new': 1, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.169
#
# ========================= 正在分析: 其中：碳化硅 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.055
#
# ========================= 正在分析: 19.黑色金属冶炼和压延加工业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 4, 'cap_low_new': 4, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.073
#
# ========================= 正在分析: 其中：钢铁 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 4, 'cap_low_new': 4, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.136
#
# ========================= 正在分析: 铁合金冶炼 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 5, 'cap_low_new': 3, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.422
#
# ========================= 正在分析: 20.有色金属冶炼和压延加工业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 6, 'cap_low_new': 1, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.269
#
# ========================= 正在分析: 其中：铝冶炼 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 4, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.020
#
# ========================= 正在分析: 铅锌冶炼 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.216
#
# ========================= 正在分析: 稀有稀土金属冶炼 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 7, 'cap_low_new': 4, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.510
#
# ========================= 正在分析: 21.金属制品业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 1, 'cap_low_new': 5, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.269
#
# ========================= 正在分析: 其中：结构性金属制品制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 6, 'cap_low_new': 2, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.180
#
# ========================= 正在分析: 22.通用设备制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 3, 'cap_low_new': 1, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.254
#
# ========================= 正在分析: 其中：风能原动设备制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 6, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.206
#
# ========================= 正在分析: 23.专用设备制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 2, 'cap_low_new': 6, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.224
#
# ========================= 正在分析: 其中：医疗仪器设备及器械制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 6, 'cap_low_new': 8, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.375
#
# ========================= 正在分析: 24.汽车制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 3, 'cap_low_new': 2, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.476
#
# ========================= 正在分析: 其中：新能源车整车制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 8, 'cap_low_new': 7, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.137
#
# ========================= 正在分析: 25.铁路、船舶、航空航天和其他运输设备制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 3, 'cap_low_new': 4, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.161
#
# ========================= 正在分析: 其中：铁路运输设备制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 1, 'cap_low_new': 3, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: -0.014
#
# ========================= 正在分析: 城市轨道交通设备制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 1, 'cap_low_new': 2, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.109
#
# ========================= 正在分析: 航空、航天器及设备制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 7, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.055
#
# ========================= 正在分析: 26.电气机械和器材制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 4, 'cap_low_new': 6, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.419
#
# ========================= 正在分析: 其中：光伏设备及元器件制造 =========================
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 8, 'cap_low_new': 1, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.031
#
# ========================= 正在分析: 27.计算机、通信和其他电子设备制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 4, 'cap_low_new': 5, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.543
#
# ========================= 正在分析: 其中：计算机制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 1, 'cap_low_new': 8, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.167
#
# ========================= 正在分析: 通信设备制造 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 1, 'cap_low_new': 3, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.449
#
# ========================= 正在分析: 28.仪器仪表制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 8, 'cap_low_new': 3, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.240
#
# ========================= 正在分析: 29.其他制造业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 5, 'cap_low_new': 8, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.395
#
# ========================= 正在分析: 30.废弃资源综合利用业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 2, 'cap_low_new': 6, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.292
#
# ========================= 正在分析: 31.金属制品、机械和设备修理业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 8, 'cap_low_new': 5, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.324
#
# ========================= 正在分析: （三）电力、热力、燃气及水生产和供应业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.255
#
# ========================= 正在分析: 1.电力、热力生产和供应业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.274
#
# ========================= 正在分析: 其中：电厂生产全部耗用电量 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 7, 'cap_low_new': 5, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.361
#
# ========================= 正在分析: 线路损失电量 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 6, 'cap_low_exp': 1}
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
#     -> 回归建模完成，调整后R²: 0.038
#
# ========================= 正在分析: 抽水蓄能抽水耗用电量 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 4, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: -0.017
#
# ========================= 正在分析: 2.燃气生产和供应业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 1, 'cap_low_new': 8, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.184
#
# ========================= 正在分析: 3.水的生产和供应业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 2, 'cap_low_new': 4, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.129
#
# ========================= 正在分析: 三、建筑业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.226
#
# ========================= 正在分析: 1.房屋建筑业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 4, 'cap_low_new': 7, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.348
#
# ========================= 正在分析: 2.土木工程建筑业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 6, 'cap_low_new': 1, 'cap_low_exp': 3}
#     -> 回归建模完成，调整后R²: 0.090
#
# ========================= 正在分析: 3.建筑安装业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 4, 'cap_low_new': 5, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.410
#
# ========================= 正在分析: 4.建筑装饰、装修和其他建筑业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.279
#
# ========================= 正在分析: 四、交通运输、仓储和邮政业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 3, 'cap_low_new': 2, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.156
#
# ========================= 正在分析: 1.铁路运输业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 1, 'cap_low_new': 6, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.135
#
# ========================= 正在分析: 其中：电气化铁路 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 1, 'cap_low_new': 8, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.074
#
# ========================= 正在分析: 2.道路运输业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.097
#
# ========================= 正在分析: 其中：城市公共交通运输 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 1, 'cap_low_new': 7, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.212
#
# ========================= 正在分析: 3.水上运输业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 1, 'cap_low_new': 7, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.078
#
# ========================= 正在分析: 其中：港口岸电 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 5, 'cap_low_new': 8, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: -0.076
#
# ========================= 正在分析: 4.航空运输业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
# d:\Software\Anaconda\envs\dianli\Lib\site-packages\statsmodels\tsa\stattools.py:1179: RuntimeWarning: invalid value encountered in divide
#   ret = cvf / (np.std(x) * np.std(y))
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 3, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.404
#
# ========================= 正在分析: 5.管道运输业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 2, 'cap_low_new': 6, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.053
#
# ========================= 正在分析: 6.多式联运和运输代理业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 4, 'cap_low_new': 3, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.257
#
# ========================= 正在分析: 7.装卸搬运和仓储业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 8, 'cap_low_new': 6, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.299
#
# ========================= 正在分析: 8.邮政业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 1, 'cap_low_new': 8, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.314
#
# ========================= 正在分析: 五、信息传输、软件和信息技术服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 7, 'cap_high_exp': 2, 'cap_low_new': 7, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.020
#
# ========================= 正在分析: 1.电信、广播电视和卫星传输服务 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 8, 'cap_low_new': 8, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.188
#
# ========================= 正在分析: 2.互联网和相关服务 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 1, 'cap_low_new': 6, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.032
#
# ========================= 正在分析: 其中：互联网数据服务 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 6, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.313
#
# ========================= 正在分析: 3.软件和信息技术服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 2, 'cap_low_new': 6, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.590
#
# ========================= 正在分析: 六、批发和零售业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 1, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.213
#
# ========================= 正在分析: 其中：充换电服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 1, 'cap_low_new': 3, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.260
#
# ========================= 正在分析: 七、住宿和餐饮业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 4, 'cap_low_new': 5, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.313
#
# ========================= 正在分析: 八、金融业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 2, 'cap_low_new': 1, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.265
#
# ========================= 正在分析: 九、房地产业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 3, 'cap_low_new': 7, 'cap_low_exp': 2}
#     -> 回归建模完成，调整后R²: 0.262
#
# ========================= 正在分析: 十、租赁和商务服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 2, 'cap_low_new': 6, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.321
#
# ========================= 正在分析: 其中：租赁业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 5, 'cap_high_exp': 2, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.224
#
# ========================= 正在分析: 十一、公共服务及管理组织 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 2, 'cap_low_new': 7, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.139
#
# ========================= 正在分析: 1.科学研究和技术服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 2, 'cap_low_new': 1, 'cap_low_exp': 6}
#     -> 回归建模完成，调整后R²: 0.241
#
# ========================= 正在分析: 其中：地质勘查 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 6, 'cap_low_new': 4, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.342
#
# ========================= 正在分析: 其中：科技推广和应用服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 4, 'cap_high_exp': 6, 'cap_low_new': 1, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.180
#
# ========================= 正在分析: 2.水利、环境和公共设施管理业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 3, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.256
#
# ========================= 正在分析: 其中：水利管理业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 1, 'cap_low_new': 5, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.162
#
# ========================= 正在分析: 其中：公共照明 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 6, 'cap_high_exp': 1, 'cap_low_new': 6, 'cap_low_exp': 4}
#     -> 回归建模完成，调整后R²: 0.230
#
# ========================= 正在分析: 3.居民服务、修理和其他服务业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 1, 'cap_high_exp': 1, 'cap_low_new': 7, 'cap_low_exp': 7}
#     -> 回归建模完成，调整后R²: 0.248
#
# ========================= 正在分析: 4.教育、文化、体育和娱乐业 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 5, 'cap_low_new': 5, 'cap_low_exp': 1}
#     -> 回归建模完成，调整后R²: 0.406
#
# ========================= 正在分析: 其中：教育 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 3, 'cap_high_exp': 2, 'cap_low_new': 3, 'cap_low_exp': 8}
#     -> 回归建模完成，调整后R²: 0.141
#
# ========================= 正在分析: 5.卫生和社会工作 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 8, 'cap_high_exp': 6, 'cap_low_new': 8, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.183
#
# ========================= 正在分析: 6.公共管理和社会组织、国际组织 =========================
#     -> 正在对电量数据进行STL季节性调整...
#     -> STL调整并一阶差分完成。
#     -> 数据平稳化完成，剩余 46 个有效数据点。
#     -> CCF分析完成，最佳滞后期: {'cap_high_new': 2, 'cap_high_exp': 8, 'cap_low_new': 7, 'cap_low_exp': 5}
#     -> 回归建模完成，调整后R²: 0.105
#
# ============================== 所有行业分析结果汇总 ==============================
#
# 各行业【最佳影响滞后期(月)】汇总:
#                   cap_high_exp  cap_high_new  cap_low_exp  cap_low_new
# 行业分类
# 全行业总计                        5             7            1            1
# A、全行业用电合计                    8             7            1            5
# 第一产业                         8             6            5            3
# 第二产业                         3             7            4            6
# 第三产业                         3             2            7            1
# ...                        ...           ...          ...          ...
# 3.居民服务、修理和其他服务业              1             1            7            7
# 4.教育、文化、体育和娱乐业               5             2            1            5
# 其中：教育                        2             3            8            3
# 5.卫生和社会工作                    6             8            5            8
# 6.公共管理和社会组织、国际组织             8             2            5            7
#
# [133 rows x 4 columns]
# 各行业【影响系数(β值 - kWh/kVA)】汇总 (绿色粗体表示统计显著):
# <style type="text/css">
# #T_bd491_row0_col0, #T_bd491_row0_col2, #T_bd491_row1_col0, #T_bd491_row1_col1, #T_bd491_row1_col2, #T_bd491_row2_col0, #T_bd491_row2_col1, #T_bd491_row2_col2, #T_bd491_row2_col3, #T_bd491_row3_col1, #T_bd491_row4_col1, #T_bd491_row4_col2, #T_bd491_row5_col1, #T_bd491_row5_col2, #T_bd491_row5_col3, #T_bd491_row6_col3, #T_bd491_row7_col2, #T_bd491_row7_col3, #T_bd491_row8_col0, #T_bd491_row8_col1, #T_bd491_row8_col2, #T_bd491_row9_col1, #T_bd491_row9_col3, #T_bd491_row10_col1, #T_bd491_row10_col2, #T_bd491_row10_col3, #T_bd491_row11_col0, #T_bd491_row11_col1, #T_bd491_row11_col2, #T_bd491_row11_col3, #T_bd491_row12_col1, #T_bd491_row12_col3, #T_bd491_row13_col3, #T_bd491_row14_col0, #T_bd491_row14_col1, #T_bd491_row14_col2, #T_bd491_row14_col3, #T_bd491_row15_col1, #T_bd491_row15_col2, #T_bd491_row15_col3, #T_bd491_row16_col1, #T_bd491_row17_col0, #T_bd491_row17_col1, #T_bd491_row17_col3, #T_bd491_row18_col1, #T_bd491_row18_col2, #T_bd491_row18_col3, #T_bd491_row19_col1, #T_bd491_row19_col2, #T_bd491_row19_col3, #T_bd491_row20_col2, #T_bd491_row21_col0, #T_bd491_row21_col1, #T_bd491_row21_col2, #T_bd491_row22_col1, #T_bd491_row23_col0, #T_bd491_row24_col0, #T_bd491_row24_col1, #T_bd491_row24_col3, #T_bd491_row25_col1, #T_bd491_row26_col0, #T_bd491_row26_col2, #T_bd491_row26_col3, #T_bd491_row27_col2, #T_bd491_row27_col3, #T_bd491_row28_col2, #T_bd491_row29_col1, #T_bd491_row29_col2, #T_bd491_row29_col3, #T_bd491_row30_col1, #T_bd491_row30_col3, #T_bd491_row31_col3, #T_bd491_row32_col0, #T_bd491_row32_col1, #T_bd491_row32_col2, #T_bd491_row33_col2, #T_bd491_row34_col1, #T_bd491_row34_col2, #T_bd491_row34_col3, #T_bd491_row35_col0, #T_bd491_row35_col1, #T_bd491_row35_col2, #T_bd491_row35_col3, #T_bd491_row36_col0, #T_bd491_row36_col3, #T_bd491_row37_col0, #T_bd491_row37_col2, #T_bd491_row38_col0, #T_bd491_row38_col2, #T_bd491_row38_col3, #T_bd491_row39_col0, #T_bd491_row39_col1, #T_bd491_row39_col2, #T_bd491_row40_col0, #T_bd491_row40_col2, #T_bd491_row40_col3, #T_bd491_row41_col0, #T_bd491_row41_col1, #T_bd491_row41_col2, #T_bd491_row41_col3, #T_bd491_row42_col0, #T_bd491_row42_col1, #T_bd491_row42_col2, #T_bd491_row43_col0, #T_bd491_row43_col1, #T_bd491_row43_col2, #T_bd491_row43_col3, #T_bd491_row44_col1, #T_bd491_row44_col2, #T_bd491_row44_col3, #T_bd491_row45_col0, #T_bd491_row45_col1, #T_bd491_row45_col2, #T_bd491_row46_col0, #T_bd491_row46_col2, #T_bd491_row47_col0, #T_bd491_row47_col2, #T_bd491_row48_col1, #T_bd491_row48_col2, #T_bd491_row49_col0, #T_bd491_row49_col1, #T_bd491_row49_col2, #T_bd491_row51_col1, #T_bd491_row51_col2, #T_bd491_row51_col3, #T_bd491_row52_col0, #T_bd491_row52_col1, #T_bd491_row52_col2, #T_bd491_row53_col1, #T_bd491_row53_col2, #T_bd491_row53_col3, #T_bd491_row54_col1, #T_bd491_row54_col2, #T_bd491_row54_col3, #T_bd491_row55_col0, #T_bd491_row55_col2, #T_bd491_row55_col3, #T_bd491_row56_col0, #T_bd491_row56_col2, #T_bd491_row56_col3, #T_bd491_row57_col0, #T_bd491_row57_col2, #T_bd491_row57_col3, #T_bd491_row58_col0, #T_bd491_row58_col2, #T_bd491_row59_col2, #T_bd491_row59_col3, #T_bd491_row60_col0, #T_bd491_row60_col1, #T_bd491_row61_col0, #T_bd491_row61_col1, #T_bd491_row61_col2, #T_bd491_row61_col3, #T_bd491_row62_col0, #T_bd491_row62_col2, #T_bd491_row62_col3, #T_bd491_row63_col2, #T_bd491_row65_col0, #T_bd491_row65_col1, #T_bd491_row65_col3, #T_bd491_row66_col1, #T_bd491_row67_col0, #T_bd491_row67_col1, #T_bd491_row67_col2, #T_bd491_row68_col0, #T_bd491_row68_col3, #T_bd491_row69_col0, #T_bd491_row69_col2, #T_bd491_row70_col1, #T_bd491_row70_col2, #T_bd491_row71_col0, #T_bd491_row71_col1, #T_bd491_row71_col2, #T_bd491_row72_col0, #T_bd491_row72_col1, #T_bd491_row72_col2, #T_bd491_row73_col0, #T_bd491_row73_col1, #T_bd491_row73_col2, #T_bd491_row73_col3, #T_bd491_row74_col0, #T_bd491_row74_col2, #T_bd491_row74_col3, #T_bd491_row75_col1, #T_bd491_row75_col2, #T_bd491_row75_col3, #T_bd491_row76_col3, #T_bd491_row77_col0, #T_bd491_row77_col1, #T_bd491_row77_col2, #T_bd491_row77_col3, #T_bd491_row ...
#   color: grey;
# }
# #T_bd491_row0_col1, #T_bd491_row0_col3, #T_bd491_row1_col3, #T_bd491_row3_col0, #T_bd491_row3_col2, #T_bd491_row3_col3, #T_bd491_row4_col0, #T_bd491_row4_col3, #T_bd491_row5_col0, #T_bd491_row6_col0, #T_bd491_row6_col1, #T_bd491_row6_col2, #T_bd491_row7_col0, #T_bd491_row7_col1, #T_bd491_row8_col3, #T_bd491_row9_col0, #T_bd491_row9_col2, #T_bd491_row10_col0, #T_bd491_row12_col0, #T_bd491_row12_col2, #T_bd491_row13_col0, #T_bd491_row13_col1, #T_bd491_row13_col2, #T_bd491_row15_col0, #T_bd491_row16_col0, #T_bd491_row16_col2, #T_bd491_row16_col3, #T_bd491_row17_col2, #T_bd491_row18_col0, #T_bd491_row19_col0, #T_bd491_row20_col0, #T_bd491_row20_col1, #T_bd491_row20_col3, #T_bd491_row21_col3, #T_bd491_row22_col0, #T_bd491_row22_col2, #T_bd491_row22_col3, #T_bd491_row23_col1, #T_bd491_row23_col2, #T_bd491_row23_col3, #T_bd491_row24_col2, #T_bd491_row2
# 完整汇总结果已保存到: E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月底电量报告全行业_净值_业扩分析结果.xlsx
#
# --- 全部分析任务完成 ---

# %%
#根据上一步CCF得出的数据，进行进一步分析可以预测出未来月份的业扩贡献电量（目前不准确）

import pandas as pd
import numpy as np
import re
from IPython.display import display

# ==============================================================================
# 0. 参数配置
# ==============================================================================
results_file_path = r'E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月底电量报告全行业_净值_业扩分析结果.xlsx'
raw_cap_data_path = r'E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月底电量报告全行业_净值.xlsx'
output_prediction_path = r'E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月度报告贡献电量预测.xlsx'

prediction_months = ['202511', '202512', '202601']  #此处修改为需要预测的月份
cap_sheet_map = {
    'cap_high_new': '高压净新装',
    'cap_high_exp': '高压净增容',
    'cap_low_new': '低压净新装',
    'cap_low_exp': '低压净增容'
}

# ==============================================================================
# 1. 加载数据 (带Sheet名和dtype修复)
# ==============================================================================
print("--- 步骤 1: 正在加载数据 ---")
try:
    # --- 关键修复 1: 明确指定sheet_name ---
    sheet_name_results = '全部详细结果'
    print(f"  -> 正在从 Sheet '{sheet_name_results}' 加载回归结果...")
    
    # --- 关键修复 2: 强制指定数值列的数据类型 ---
    xls_results = pd.ExcelFile(results_file_path)
    # 检查sheet是否存在
    if sheet_name_results not in xls_results.sheet_names:
        raise ValueError(f"在文件 {results_file_path} 中找不到名为 '{sheet_name_results}' 的Sheet。")
    
    df_temp = pd.read_excel(xls_results, sheet_name=sheet_name_results, nrows=0)
    dtype_dict = {col: float for col in df_temp.columns if 'β' in col or 'p_' in col or 'R-squared' in col or 'k_' in col}
    
    df_results = pd.read_excel(results_file_path, sheet_name=sheet_name_results, index_col=0, dtype=dtype_dict)
    
    df_results.index = df_results.index.astype(str).str.strip()
    df_results.index.name = '行业分类'
    print("  -> 回归分析结果加载成功。")

    # (业扩数据加载部分保持不变)
    all_cap_data_long = []
    xls_cap = pd.ExcelFile(raw_cap_data_path)
    available_sheets = xls_cap.sheet_names
    for var_name, sheet_name in cap_sheet_map.items():
        if sheet_name in available_sheets:
            df = pd.read_excel(raw_cap_data_path, sheet_name=sheet_name)
            df['分类'] = df['分类'].astype(str).str.strip()
            valid_date_cols = [col for col in df.columns if re.match(r'^\d{6}$', str(col).split('.')[0])]
            df = df[['分类'] + valid_date_cols]
            df_long = df.melt(id_vars='分类', var_name='date', value_name=var_name)
            df_long['date'] = pd.to_datetime(df_long['date'].astype(str), format='%Y%m')
            df_long[var_name] = pd.to_numeric(df_long[var_name], errors='coerce')
            all_cap_data_long.append(df_long.set_index(['分类', 'date']))
    if not all_cap_data_long: raise ValueError("未能加载任何业扩数据。")
    df_cap_raw = pd.concat(all_cap_data_long, axis=1)
    print("  -> 原始业扩数据加载成功。")
except Exception as e:
    raise RuntimeError(f"加载数据时出错: {e}")

# ==============================================================================
# 2. 计算业扩贡献电量 (无p值过滤)
# ==============================================================================
print("\n--- 步骤 2: 正在计算业扩贡献电量 (无p值过滤) ---")
df_cap_diff = df_cap_raw.groupby(level='分类').diff(1)
all_predictions = []
for industry_name, row in df_results.iterrows():
    print(f"  -> 正在为行业 '{industry_name}' 进行计算...")
    if industry_name not in df_cap_diff.index.get_level_values('分类'):
        print(f"     - 警告: 在业扩数据中未找到行业 '{industry_name}'，跳过。")
        continue
    industry_cap_diff = df_cap_diff.loc[industry_name]
    for month_str in prediction_months:
        target_month = pd.to_datetime(month_str, format='%Y%m')
        total_contribution_current_year, total_contribution_last_year = 0, 0
        target_month_last_year = target_month - pd.DateOffset(years=1)
        for cap_var in cap_sheet_map.keys():
            k = int(row.get(f'k_{cap_var}', 0))
            beta = row.get(f'β_{cap_var}', 0)
            required_date_current = target_month - pd.DateOffset(months=k)
            if required_date_current in industry_cap_diff.index:
                cap_increment = industry_cap_diff.loc[required_date_current, cap_var]
                if pd.notna(cap_increment): total_contribution_current_year += beta * cap_increment
            required_date_last = target_month_last_year - pd.DateOffset(months=k)
            if required_date_last in industry_cap_diff.index:
                cap_increment_last = industry_cap_diff.loc[required_date_last, cap_var]
                if pd.notna(cap_increment_last): total_contribution_last_year += beta * cap_increment_last
        all_predictions.append({'行业分类': industry_name, '预测月份': target_month, '业扩贡献电量': total_contribution_current_year, '去年同期贡献': total_contribution_last_year})
df_predictions = pd.DataFrame(all_predictions)

# ==============================================================================
# 3. 结果展示
# ==============================================================================
print("\n--- 步骤 3: 结果展示 ---")
if df_predictions.empty:
    print("未能计算出任何预测结果。")
else:
    df_pivot = df_predictions.pivot(index='行业分类', columns='预测月份', values=['业扩贡献电量', '去年同期贡献'])
    cols_ordered, new_cols = [], []
    for month_dt in sorted(df_predictions['预测月份'].unique()):
        cols_ordered.extend([('业扩贡献电量', month_dt), ('去年同期贡献', month_dt)])
        month_str_display = month_dt.strftime('%Y-%m')
        new_cols.extend([f'{month_str_display} 贡献 (万kWh)', f'{month_dt - pd.DateOffset(years=1):%Y-%m} 同期贡献 (万kWh)'])
    df_pivot = df_pivot[cols_ordered]; df_pivot.columns = new_cols
    print("\n【情景模拟】业扩潜在贡献电量预测 (单位: 万kWh):")
    display(df_pivot.style.format("{:,.6f}").background_gradient(cmap='RdYlGn', axis=None, low=0.4, high=0.4))
    df_pivot.to_excel(output_prediction_path)
    print(f"\n预测结果已保存到: {output_prediction_path}")
# Out:
# --- 步骤 1: 正在加载数据 ---
#   -> 正在从 Sheet '全部详细结果' 加载回归结果...
#   -> 回归分析结果加载成功。
#   -> 原始业扩数据加载成功。
#
# --- 步骤 2: 正在计算业扩贡献电量 (无p值过滤) ---
#   -> 正在为行业 '全行业总计' 进行计算...
#   -> 正在为行业 'A、全行业用电合计' 进行计算...
#   -> 正在为行业 '第一产业' 进行计算...
#   -> 正在为行业 '第二产业' 进行计算...
#   -> 正在为行业 '第三产业' 进行计算...
#   -> 正在为行业 'B、城乡居民生活用电合计' 进行计算...
#   -> 正在为行业 '城镇居民' 进行计算...
#   -> 正在为行业 '乡村居民' 进行计算...
#   -> 正在为行业 '全行业用电分类' 进行计算...
#   -> 正在为行业 '一、农、林、牧、渔业' 进行计算...
#   -> 正在为行业 '1.农业' 进行计算...
#   -> 正在为行业 '2.林业' 进行计算...
#   -> 正在为行业 '3.畜牧业' 进行计算...
#   -> 正在为行业 '4.渔业' 进行计算...
#   -> 正在为行业 '5.农、林、牧、渔专业及辅助性活动' 进行计算...
#   -> 正在为行业 '其中：排灌' 进行计算...
#   -> 正在为行业 '二、工业' 进行计算...
#   -> 正在为行业 '（一）采矿业' 进行计算...
#   -> 正在为行业 '1.煤炭开采和洗选业' 进行计算...
#   -> 正在为行业 '2.石油和天燃气开采业' 进行计算...
#   -> 正在为行业 '3.黑色金属矿采选业' 进行计算...
#   -> 正在为行业 '4.有色金属矿采选业' 进行计算...
#   -> 正在为行业 '5.非金属矿采选业' 进行计算...
#   -> 正在为行业 '6.其他采矿业' 进行计算...
#   -> 正在为行业 '（二）制造业' 进行计算...
#   -> 正在为行业 '1.农副食品加工业' 进行计算...
#   -> 正在为行业 '2.食品制造业' 进行计算...
#   -> 正在为行业 '3.酒、饮料及精制茶制造业' 进行计算...
#   -> 正在为行业 '4.烟草制品业' 进行计算...
#   -> 正在为行业 '5.纺织业' 进行计算...
#   -> 正在为行业 '6.纺织服装、服饰业' 进行计算...
#   -> 正在为行业 '7.皮革、毛皮、羽毛及其制品和制鞋业' 进行计算...
#   -> 正在为行业 '8.木材加工和木、竹、藤、棕、草制品业' 进行计算...
#   -> 正在为行业 '9.家具制造业' 进行计算...
#   -> 正在为行业 '10.造纸和纸制品业' 进行计算...
#   -> 正在为行业 '11.印刷和记录媒介复制业' 进行计算...
#   -> 正在为行业 '12.文教、工美、体育和娱乐用品制造业' 进行计算...
#   -> 正在为行业 '其中：体育用品制造' 进行计算...
#   -> 正在为行业 '13.石油、煤炭及其他燃料加工业' 进行计算...
#   -> 正在为行业 '其中：煤化工' 进行计算...
#   -> 正在为行业 '14.化学原料和化学制品制造业' 进行计算...
#   -> 正在为行业 '其中：氯碱' 进行计算...
#   -> 正在为行业 '电石' 进行计算...
#   -> 正在为行业 '黄磷' 进行计算...
#   -> 正在为行业 '其中：肥料制造' 进行计算...
#   -> 正在为行业 '15.医药制造业' 进行计算...
#   -> 正在为行业 '其中：中成药生产' 进行计算...
#   -> 正在为行业 '生物药品制品制造' 进行计算...
#   -> 正在为行业 '16.化学纤维制造业' 进行计算...
#   -> 正在为行业 '17.橡胶和塑料制品业' 进行计算...
#   -> 正在为行业 '其中：橡胶制品业' 进行计算...
#   -> 正在为行业 '塑料制品业' 进行计算...
#   -> 正在为行业 '18.非金属矿物制品业' 进行计算...
#   -> 正在为行业 '其中：水泥制造' 进行计算...
#   -> 正在为行业 '玻璃制造' 进行计算...
#   -> 正在为行业 '陶瓷制品制造' 进行计算...
#   -> 正在为行业 '其中：碳化硅' 进行计算...
#   -> 正在为行业 '19.黑色金属冶炼和压延加工业' 进行计算...
#   -> 正在为行业 '其中：钢铁' 进行计算...
#   -> 正在为行业 '铁合金冶炼' 进行计算...
#   -> 正在为行业 '20.有色金属冶炼和压延加工业' 进行计算...
#   -> 正在为行业 '其中：铝冶炼' 进行计算...
#   -> 正在为行业 '铅锌冶炼' 进行计算...
#   -> 正在为行业 '稀有稀土金属冶炼' 进行计算...
#   -> 正在为行业 '21.金属制品业' 进行计算...
#   -> 正在为行业 '其中：结构性金属制品制造' 进行计算...
#   -> 正在为行业 '22.通用设备制造业' 进行计算...
#   -> 正在为行业 '其中：风能原动设备制造' 进行计算...
#   -> 正在为行业 '23.专用设备制造业' 进行计算...
#   -> 正在为行业 '其中：医疗仪器设备及器械制造' 进行计算...
#   -> 正在为行业 '24.汽车制造业' 进行计算...
#   -> 正在为行业 '其中：新能源车整车制造' 进行计算...
#   -> 正在为行业 '25.铁路、船舶、航空航天和其他运输设备制造业' 进行计算...
#   -> 正在为行业 '其中：铁路运输设备制造' 进行计算...
#   -> 正在为行业 '城市轨道交通设备制造' 进行计算...
#   -> 正在为行业 '航空、航天器及设备制造' 进行计算...
#   -> 正在为行业 '26.电气机械和器材制造业' 进行计算...
#   -> 正在为行业 '其中：光伏设备及元器件制造' 进行计算...
#   -> 正在为行业 '27.计算机、通信和其他电子设备制造业' 进行计算...
#   -> 正在为行业 '其中：计算机制造' 进行计算...
#   -> 正在为行业 '通信设备制造' 进行计算...
#   -> 正在为行业 '28.仪器仪表制造业' 进行计算...
#   -> 正在为行业 '29.其他制造业' 进行计算...
#   -> 正在为行业 '30.废弃资源综合利用业' 进行计算...
#   -> 正在为行业 '31.金属制品、机械和设备修理业' 进行计算...
#   -> 正在为行业 '（三）电力、热力、燃气及水生产和供应业' 进行计算...
#   -> 正在为行业 '1.电力、热力生产和供应业' 进行计算...
#   -> 正在为行业 '其中：电厂生产全部耗用电量' 进行计算...
#   -> 正在为行业 '线路损失电量' 进行计算...
#   -> 正在为行业 '抽水蓄能抽水耗用电量' 进行计算...
#   -> 正在为行业 '2.燃气生产和供应业' 进行计算...
#   -> 正在为行业 '3.水的生产和供应业' 进行计算...
#   -> 正在为行业 '三、建筑业' 进行计算...
#   -> 正在为行业 '1.房屋建筑业' 进行计算...
#   -> 正在为行业 '2.土木工程建筑业' 进行计算...
#   -> 正在为行业 '3.建筑安装业' 进行计算...
#   -> 正在为行业 '4.建筑装饰、装修和其他建筑业' 进行计算...
#   -> 正在为行业 '四、交通运输、仓储和邮政业' 进行计算...
#   -> 正在为行业 '1.铁路运输业' 进行计算...
#   -> 正在为行业 '其中：电气化铁路' 进行计算...
#   -> 正在为行业 '2.道路运输业' 进行计算...
#   -> 正在为行业 '其中：城市公共交通运输' 进行计算...
#   -> 正在为行业 '3.水上运输业' 进行计算...
#   -> 正在为行业 '其中：港口岸电' 进行计算...
#   -> 正在为行业 '4.航空运输业' 进行计算...
#   -> 正在为行业 '5.管道运输业' 进行计算...
#   -> 正在为行业 '6.多式联运和运输代理业' 进行计算...
#   -> 正在为行业 '7.装卸搬运和仓储业' 进行计算...
#   -> 正在为行业 '8.邮政业' 进行计算...
#   -> 正在为行业 '五、信息传输、软件和信息技术服务业' 进行计算...
#   -> 正在为行业 '1.电信、广播电视和卫星传输服务' 进行计算...
#   -> 正在为行业 '2.互联网和相关服务' 进行计算...
#   -> 正在为行业 '其中：互联网数据服务' 进行计算...
#   -> 正在为行业 '3.软件和信息技术服务业' 进行计算...
#   -> 正在为行业 '六、批发和零售业' 进行计算...
#   -> 正在为行业 '其中：充换电服务业' 进行计算...
#   -> 正在为行业 '七、住宿和餐饮业' 进行计算...
#   -> 正在为行业 '八、金融业' 进行计算...
#   -> 正在为行业 '九、房地产业' 进行计算...
#   -> 正在为行业 '十、租赁和商务服务业' 进行计算...
#   -> 正在为行业 '其中：租赁业' 进行计算...
#   -> 正在为行业 '十一、公共服务及管理组织' 进行计算...
#   -> 正在为行业 '1.科学研究和技术服务业' 进行计算...
#   -> 正在为行业 '其中：地质勘查' 进行计算...
#   -> 正在为行业 '其中：科技推广和应用服务业' 进行计算...
#   -> 正在为行业 '2.水利、环境和公共设施管理业' 进行计算...
#   -> 正在为行业 '其中：水利管理业' 进行计算...
#   -> 正在为行业 '其中：公共照明' 进行计算...
#   -> 正在为行业 '3.居民服务、修理和其他服务业' 进行计算...
#   -> 正在为行业 '4.教育、文化、体育和娱乐业' 进行计算...
#   -> 正在为行业 '其中：教育' 进行计算...
#   -> 正在为行业 '5.卫生和社会工作' 进行计算...
#   -> 正在为行业 '6.公共管理和社会组织、国际组织' 进行计算...
#
# --- 步骤 3: 结果展示 ---
#
# 【情景模拟】业扩潜在贡献电量预测 (单位: 万kWh):
# <style type="text/css">
# #T_a2564_row0_col0, #T_a2564_row0_col1, #T_a2564_row0_col2, #T_a2564_row0_col3, #T_a2564_row0_col4, #T_a2564_row0_col5, #T_a2564_row1_col1, #T_a2564_row1_col2, #T_a2564_row1_col4, #T_a2564_row2_col0, #T_a2564_row2_col2, #T_a2564_row2_col4, #T_a2564_row2_col5, #T_a2564_row3_col0, #T_a2564_row3_col1, #T_a2564_row3_col2, #T_a2564_row3_col3, #T_a2564_row3_col4, #T_a2564_row3_col5, #T_a2564_row4_col0, #T_a2564_row4_col1, #T_a2564_row4_col2, #T_a2564_row4_col3, #T_a2564_row4_col4, #T_a2564_row4_col5, #T_a2564_row5_col0, #T_a2564_row5_col2, #T_a2564_row6_col1, #T_a2564_row6_col3, #T_a2564_row6_col5, #T_a2564_row7_col0, #T_a2564_row7_col4, #T_a2564_row7_col5, #T_a2564_row8_col1, #T_a2564_row8_col2, #T_a2564_row8_col3, #T_a2564_row8_col4, #T_a2564_row8_col5, #T_a2564_row9_col0, #T_a2564_row9_col1, #T_a2564_row9_col2, #T_a2564_row9_col3, #T_a2564_row9_col4, #T_a2564_row9_col5, #T_a2564_row10_col0, #T_a2564_row10_col1, #T_a2564_row10_col2, #T_a2564_row10_col3, #T_a2564_row10_col4, #T_a2564_row10_col5, #T_a2564_row11_col2, #T_a2564_row11_col4, #T_a2564_row11_col5, #T_a2564_row12_col1, #T_a2564_row12_col3, #T_a2564_row13_col0, #T_a2564_row13_col2, #T_a2564_row13_col5, #T_a2564_row14_col0, #T_a2564_row14_col1, #T_a2564_row14_col3, #T_a2564_row14_col4, #T_a2564_row14_col5, #T_a2564_row15_col0, #T_a2564_row15_col1, #T_a2564_row15_col2, #T_a2564_row15_col3, #T_a2564_row15_col4, #T_a2564_row15_col5, #T_a2564_row16_col0, #T_a2564_row17_col2, #T_a2564_row17_col4, #T_a2564_row18_col0, #T_a2564_row18_col1, #T_a2564_row18_col2, #T_a2564_row18_col4, #T_a2564_row18_col5, #T_a2564_row19_col0, #T_a2564_row19_col1, #T_a2564_row19_col2, #T_a2564_row19_col3, #T_a2564_row19_col4, #T_a2564_row19_col5, #T_a2564_row20_col0, #T_a2564_row20_col1, #T_a2564_row20_col2, #T_a2564_row20_col3, #T_a2564_row20_col4, #T_a2564_row20_col5, #T_a2564_row21_col0, #T_a2564_row21_col1, #T_a2564_row21_col3, #T_a2564_row21_col5, #T_a2564_row22_col1, #T_a2564_row22_col2, #T_a2564_row22_col3, #T_a2564_row22_col4, #T_a2564_row22_col5, #T_a2564_row23_col0, #T_a2564_row23_col1, #T_a2564_row23_col2, #T_a2564_row23_col3, #T_a2564_row23_col4, #T_a2564_row23_col5, #T_a2564_row24_col0, #T_a2564_row24_col1, #T_a2564_row24_col2, #T_a2564_row24_col3, #T_a2564_row24_col4, #T_a2564_row24_col5, #T_a2564_row25_col0, #T_a2564_row25_col1, #T_a2564_row25_col3, #T_a2564_row25_col5, #T_a2564_row26_col2, #T_a2564_row26_col3, #T_a2564_row26_col5, #T_a2564_row27_col4, #T_a2564_row28_col0, #T_a2564_row28_col1, #T_a2564_row28_col2, #T_a2564_row28_col3, #T_a2564_row28_col4, #T_a2564_row28_col5, #T_a2564_row29_col0, #T_a2564_row29_col1, #T_a2564_row29_col3, #T_a2564_row29_col5, #T_a2564_row30_col2, #T_a2564_row31_col0, #T_a2564_row31_col1, #T_a2564_row32_col0, #T_a2564_row32_col1, #T_a2564_row32_col4, #T_a2564_row33_col2, #T_a2564_row33_col3, #T_a2564_row33_col4, #T_a2564_row33_col5, #T_a2564_row34_col0, #T_a2564_row34_col1, #T_a2564_row34_col2, #T_a2564_row34_col3, #T_a2564_row34_col4, #T_a2564_row34_col5, #T_a2564_row35_col0, #T_a2564_row35_col3, #T_a2564_row36_col0, #T_a2564_row36_col1, #T_a2564_row36_col2, #T_a2564_row36_col3, #T_a2564_row36_col4, #T_a2564_row36_col5, #T_a2564_row37_col0, #T_a2564_row37_col1, #T_a2564_row37_col2, #T_a2564_row37_col3, #T_a2564_row37_col4, #T_a2564_row37_col5, #T_a2564_row38_col0, #T_a2564_row38_col1, #T_a2564_row38_col2, #T_a2564_row38_col3, #T_a2564_row38_col4, #T_a2564_row38_col5, #T_a2564_row39_col0, #T_a2564_row39_col1, #T_a2564_row39_col2, #T_a2564_row39_col3, #T_a2564_row39_col4, #T_a2564_row39_col5, #T_a2564_row40_col0, #T_a2564_row40_col1, #T_a2564_row40_col2, #T_a2564_row40_col3, #T_a2564_row40_col4, #T_a2564_row40_col5, #T_a2564_row41_col0, #T_a2564_row41_col1, #T_a2564_row41_col2, #T_a2564_row41_col3, #T_a2564_row41_col4, #T_a2564_row41_col5, #T_a2564_row42_col0, #T_a2564_row42_col2, #T_a2564_row42_col3, #T_a2564_row42_col4, #T_a2564_row42_col5, #T_a2564_row43_col0, #T_a2564_row43_col1, #T_a2564_row43_col2, #T_a2564_row43_col4, #T_a2564_row43_col5, #T_a2564_row ...
# 预测结果已保存到: E:\A智网\业扩分析\12月分析\11月业扩月度报告\12.17\11月业扩月度报告贡献电量预测.xlsx
