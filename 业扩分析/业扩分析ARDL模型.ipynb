# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.api import ARDL, ardl_select_order
from statsmodels.tsa.stattools import coint
from IPython.display import display, Markdown
import re
import warnings

warnings.filterwarnings("ignore")

# --- 1. SOTA级参数与环境配置 ---
# ==============================================================================
FILE_PATH = r'E:\A智网\业扩分析\业扩ARDL模型\7月业扩月底电量报告全行业_净值.xlsx' 
OUTPUT_PATH = r'E:\A智网\业扩分析\业扩ARDL模型\ARDL分析报告_无春节变量版.xlsx'
SHEET_MAP = {
    'kwh': '电量', 
    'cap_high_new': '高压净新装', 
    'cap_high_exp': '高压净增容',
    'cap_low_new': '低压净新装', 
    'cap_low_exp': '低压净增容'
}
SIGNIFICANCE_LEVEL = 0.1
MAX_LAGS = 4
BOUNDS_TEST_ALPHA = '5%' 

# --- 2. SOTA级数据加载与特征工程 (已简化) ---
# ==============================================================================
def load_and_engineer_features(file_path, sheet_map):
    print("--- SOTA Step 1: Loading Data & Feature Engineering ---")
    all_data = {}
    for var, sheet in sheet_map.items():
        try:
            df = pd.read_excel(file_path, sheet_name=sheet)
            df['分类'] = df['分类'].astype(str).str.strip()
            
            date_cols = [c for c in df.columns if re.match(r'^\d{6}$', str(c).split('.')[0])]
            df_subset = df[['分类'] + date_cols]
            
            df_long = df_subset.melt(id_vars=['分类'], var_name='date', value_name=var)
            
            df_long['date'] = pd.to_datetime(df_long['date'].astype(str), format='%Y%m')
            df_long[var] = pd.to_numeric(df_long[var], errors='coerce').fillna(0)
            all_data[var] = df_long.set_index(['分类', 'date'])
            
        except Exception as e:
            raise RuntimeError(f"Error processing sheet '{sheet}' for variable '{var}': {e}")
            
    df_full = pd.concat(all_data.values(), axis=1)
    
    print("  -> Data loaded successfully.")
    return df_full


# --- 3. SOTA级核心分析流程 (保证DataFrame结构完整性) ---
# ==============================================================================
def run_sota_ardl_analysis(df_full):
    print("\n--- SOTA Step 2: Running Industry-by-Industry ARDL Analysis ---")
    
    industries = df_full.index.get_level_values('分类').unique()
    results_list = []
    
    # 【SOTA 终极修复】定义一个完整的列名模板
    # 确保无论成功失败，DataFrame的结构都保持一致
    dynamic_cols = [c for c in df_full.columns if c != 'kwh']
    
    all_col_names = ['行业分类', 'R-squared_adj', 'Bounds_Test_F_stat', 
                     f'Bounds_Test_Crit_Val_{BOUNDS_TEST_ALPHA}', 'Is_Cointegrated', 
                     'Coint_Test_pval(EG)', 'Bounds_Test_Method', 'speed_of_adj']
    for col in dynamic_cols:
        all_col_names.extend([f'β_long_{col}', f'p_long_{col}', f'β_short_{col}'])
    
    for industry in industries:
        print(f"\n{'='*25} Analyzing: {industry} {'='*25}")
        
        # 使用模板初始化结果字典，所有值默认为 np.nan
        result = {col: np.nan for col in all_col_names}
        result['行业分类'] = industry
        
        df_industry = df_full.loc[industry].dropna()
        if len(df_industry) < 40:
            print("    -> Insufficient data points (< 40), skipping.")
            result['R-squared_adj'] = 'Skipped: <40 data points'
            results_list.append(result)
            continue

        endog, exog = df_industry['kwh'], df_industry.drop(columns='kwh')
        
        try:
            coint_test_pval = coint(endog, exog)[1]
            print(f"    -> Engle-Granger Cointegration Test p-value: {coint_test_pval:.4f}")
            result['Coint_Test_pval(EG)'] = coint_test_pval
        except Exception as e:
            print(f"    -> Engle-Granger test failed: {e}")
            result['Coint_Test_pval(EG)'] = f'Error: {e}'

        try:
            sel_order = ardl_select_order(
                endog, maxlag=MAX_LAGS, exog=exog, 
                maxorder=MAX_LAGS, ic='aic', trend='c'
            )
            print(f"    -> Selected Order: AR={sel_order.ar_lags}, DL={sel_order.dl_lags}")
            model_fit = sel_order.model.fit()
            
            # --- 成功路径：填充所有结果 ---
            result['R-squared_adj'] = model_fit.rsquared_adj
            
            if hasattr(model_fit, 'bounds_test'):
                print("    -> Model object has `bounds_test` method. Performing test.")
                try:
                    bounds_test_summary = model_fit.bounds_test()
                    result['Bounds_Test_F_stat'] = bounds_test_summary.statistic
                    result[f'Bounds_Test_Crit_Val_{BOUNDS_TEST_ALPHA}'] = bounds_test_summary.crit_vals[BOUNDS_TEST_ALPHA][1]
                    result['Is_Cointegrated'] = 'Yes' if result['Bounds_Test_F_stat'] > result[f'Bounds_Test_Crit_Val_{BOUNDS_TEST_ALPHA}'] else 'No'
                    result['Bounds_Test_Method'] = 'Official Bounds Test'
                except Exception as e:
                    print(f"    -> WARNING: `bounds_test()` call failed: {e}. Test skipped.")
                    result['Is_Cointegrated'] = 'Error'
                    result['Bounds_Test_Method'] = 'Failed'
            else:
                print("    -> WARNING: Model object lacks `bounds_test` method. Test skipped.")
                result['Is_Cointegrated'] = 'N/A (Not applicable)'
                result['Bounds_Test_Method'] = 'N/A (Method unavailable)'

            long_run_params = model_fit.long_run_params
            ecm_params = model_fit.ecm_params
            
            for exog_var in exog.columns:
                if exog_var in long_run_params.index:
                    result[f'β_long_{exog_var}'] = long_run_params.loc[exog_var, 'coeff']
                    result[f'p_long_{exog_var}'] = long_run_params.loc[exog_var, 'pvalue']
                
                short_run_param_name = f'L0.{exog_var}'
                if short_run_param_name in ecm_params.index:
                    result[f'β_short_{exog_var}'] = ecm_params.loc[short_run_param_name, 'coeff']
            
            ect_param_name = 'ECT.L1'
            if ect_param_name in ecm_params.index:
                result['speed_of_adj'] = ecm_params.loc[ect_param_name, 'coeff']
            
            print(f"    -> Analysis complete. Adj R²: {result['R-squared_adj']:.3f}")

        except Exception as e:
            # --- 失败路径：只记录错误信息 ---
            print(f"    -> CRITICAL ERROR for '{industry}': {e}, skipping.")
            result['R-squared_adj'] = f'Error: {e}'
        
        # 无论成功或失败，都将结构完整的 result 添加到列表中
        results_list.append(result)
        
    return pd.DataFrame(results_list)

# --- 4. SOTA级结果展示与保存 (保持不变) ---
# ==============================================================================
def display_sota_results(df_summary, output_path):
    if df_summary.empty:
        print("\nNo industries could be analyzed.")
        return

    print(f"\n{'='*30} SOTA ARDL Analysis Summary {'='*30}")
    df_summary.set_index('行业分类', inplace=True)

    is_cointegrated = df_summary['Is_Cointegrated'] == 'Yes'

    def style_table(df, p_col_prefix, is_coint):
        styles = pd.DataFrame('', index=df.index, columns=df.columns)
        p_cols_in_summary = {col for col in df_summary.columns if col.startswith(p_col_prefix)}
        
        for beta_col in df.columns:
            var_name = beta_col.replace('β_long_', '').replace('β_short_', '')
            pval_col = p_col_prefix + var_name
            
            if pval_col in p_cols_in_summary:
                is_significant = pd.to_numeric(df_summary[pval_col], errors='coerce').fillna(1.0) < SIGNIFICANCE_LEVEL
                styles[beta_col] = np.where(is_significant & is_coint, 'font-weight: bold; color: green;', 
                                        np.where(is_significant, 'font-weight: bold; color: orange;', 'color: grey;'))
        return styles

    beta_long_cols = sorted([c for c in df_summary.columns if c.startswith('β_long_')])
    df_betas_long = df_summary[beta_long_cols].rename(columns=lambda c: c.replace('β_long_', ''))
    display(Markdown("### 各行业【长期影响系数 β_long】(kWh/kVA)"))
    display(Markdown("绿色粗体: **显著**且存在长期协整关系; 橙色粗体: **显著**但无长期协整关系; 灰色: 不显著"))
    display(df_betas_long.style.format("{:.2f}", na_rep="-").apply(style_table, p_col_prefix='p_long_', is_coint=is_cointegrated, axis=None))
    
    beta_short_cols = sorted([c for c in df_summary.columns if c.startswith('β_short_')])
    df_betas_short = df_summary[beta_short_cols].rename(columns=lambda c: c.replace('β_short_', ''))
    display(Markdown("### 各行业【短期冲击系数 β_short】(当期影响)"))
    display(df_betas_short.style.format("{:.2f}", na_rep="-"))
    
    with pd.ExcelWriter(output_path) as writer:
        df_betas_long.to_excel(writer, sheet_name='长期影响系数(β_long)')
        df_betas_short.to_excel(writer, sheet_name='短期冲击系数(β_short)')
        df_summary.to_excel(writer, sheet_name='全部详细结果')
    print(f"\nFull summary report saved to: {output_path}")

# --- 5. 执行主程序 ---
# ==============================================================================
if __name__ == '__main__':
    main_df = load_and_engineer_features(FILE_PATH, SHEET_MAP)
    sota_results = run_sota_ardl_analysis(main_df)
    display_sota_results(sota_results, OUTPUT_PATH)
    print("\n--- State-of-the-Art Analysis Complete ---")
# Out:
# --- SOTA Step 1: Loading Data & Feature Engineering ---
#   -> Data loaded successfully.
#
# --- SOTA Step 2: Running Industry-by-Industry ARDL Analysis ---
#
# ========================= Analyzing: 全行业总计 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.2279
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2, 3, 4], 'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0]}
#     -> CRITICAL ERROR for '全行业总计': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: A、全行业用电合计 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0330
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2, 3, 4], 'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for 'A、全行业用电合计': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 第一产业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0309
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2, 3, 4], 'cap_high_exp': [0, 1, 2], 'cap_low_new': [0], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '第一产业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 第二产业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0003
#     -> Selected Order: AR=None, DL={'cap_high_new': [0, 1, 2], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1]}
#     -> CRITICAL ERROR for '第二产业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 第三产业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9994
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '第三产业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: B、城乡居民生活用电合计 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0048
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2, 3, 4], 'cap_high_exp': [0, 1], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for 'B、城乡居民生活用电合计': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 二、工业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0003
#     -> Selected Order: AR=None, DL={'cap_high_new': [0, 1, 2], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1]}
#     -> CRITICAL ERROR for '二、工业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: （二）制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.6668
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0, 1, 2, 3], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1, 2], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '（二）制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 13.石油、煤炭及其他燃料加工业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9469
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0, 1, 2], 'cap_high_exp': [0, 1], 'cap_low_new': [0, 1], 'cap_low_exp': [0]}
#     -> CRITICAL ERROR for '13.石油、煤炭及其他燃料加工业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 14.化学原料和化学制品制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.3091
#     -> Selected Order: AR=[1], DL={'cap_low_new': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '14.化学原料和化学制品制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 15.医药制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9995
#     -> Selected Order: AR=[1], DL={'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0, 1, 2], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '15.医药制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 16.化学纤维制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0033
#     -> Selected Order: AR=[1], DL={}
#     -> CRITICAL ERROR for '16.化学纤维制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 17.橡胶和塑料制品业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0002
#     -> Selected Order: AR=None, DL={'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0, 1, 2, 3], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '17.橡胶和塑料制品业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 18.非金属矿物制品业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0002
#     -> Selected Order: AR=None, DL={'cap_high_new': [0, 1], 'cap_low_new': [0, 1, 2]}
#     -> CRITICAL ERROR for '18.非金属矿物制品业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 19.黑色金属冶炼和压延加工业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9770
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0, 1], 'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_exp': [0, 1, 2]}
#     -> CRITICAL ERROR for '19.黑色金属冶炼和压延加工业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 20.有色金属冶炼和压延加工业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.8482
#     -> Selected Order: AR=None, DL={'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1], 'cap_low_exp': [0, 1]}
#     -> CRITICAL ERROR for '20.有色金属冶炼和压延加工业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 21.金属制品业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0004
#     -> Selected Order: AR=[1], DL={'cap_high_exp': [0, 1, 2], 'cap_low_new': [0, 1]}
#     -> CRITICAL ERROR for '21.金属制品业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 22.通用设备制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0000
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2, 3], 'cap_high_exp': [0, 1, 2], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '22.通用设备制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 23.专用设备制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.1805
#     -> Selected Order: AR=[1], DL={'cap_low_new': [0, 1, 2], 'cap_low_exp': [0]}
#     -> CRITICAL ERROR for '23.专用设备制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 24.汽车制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0752
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '24.汽车制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 25.铁路、船舶、航空航天和其他运输设备制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.5323
#     -> Selected Order: AR=[1], DL={'cap_high_new': [0, 1], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1, 2]}
#     -> CRITICAL ERROR for '25.铁路、船舶、航空航天和其他运输设备制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 26.电气机械和器材制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9488
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0, 1, 2], 'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0]}
#     -> CRITICAL ERROR for '26.电气机械和器材制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 27.计算机、通信和其他电子设备制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9732
#     -> Selected Order: AR=[1], DL={'cap_high_exp': [0], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '27.计算机、通信和其他电子设备制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 28.仪器仪表制造业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.8788
#     -> Selected Order: AR=[1], DL={'cap_high_exp': [0], 'cap_low_new': [0], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '28.仪器仪表制造业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 三、建筑业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0207
#     -> Selected Order: AR=None, DL={'cap_high_new': [0, 1], 'cap_high_exp': [0, 1, 2], 'cap_low_new': [0, 1, 2, 3], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '三、建筑业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 四、交通运输、仓储和邮政业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.7517
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0], 'cap_high_exp': [0, 1, 2], 'cap_low_new': [0], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '四、交通运输、仓储和邮政业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 五、信息传输、软件和信息技术服务业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9998
#     -> Selected Order: AR=[1], DL={'cap_high_new': [0, 1, 2], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0, 1, 2, 3, 4]}
#     -> CRITICAL ERROR for '五、信息传输、软件和信息技术服务业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 六、批发和零售业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.5421
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2, 3], 'cap_high_exp': [0, 1, 2, 3], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '六、批发和零售业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 七、住宿和餐饮业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9942
#     -> Selected Order: AR=[1, 2, 3], DL={'cap_high_new': [0, 1, 2, 3], 'cap_low_new': [0, 1, 2, 3, 4], 'cap_low_exp': [0, 1]}
#     -> CRITICAL ERROR for '七、住宿和餐饮业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 八、金融业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.5823
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0], 'cap_high_exp': [0], 'cap_low_new': [0], 'cap_low_exp': [0, 1, 2, 3]}
#     -> CRITICAL ERROR for '八、金融业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 九、房地产业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9997
#     -> Selected Order: AR=[1, 2], DL={'cap_high_new': [0, 1, 2, 3, 4], 'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_exp': [0]}
#     -> CRITICAL ERROR for '九、房地产业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 十、租赁和商务服务业 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.0726
#     -> Selected Order: AR=[1, 2, 3], DL={'cap_high_new': [0, 1], 'cap_high_exp': [0, 1, 2, 3, 4], 'cap_low_new': [0]}
#     -> CRITICAL ERROR for '十、租赁和商务服务业': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ========================= Analyzing: 十一、公共服务及管理组织 =========================
#     -> Engle-Granger Cointegration Test p-value: 0.9964
#     -> Selected Order: AR=[1, 2, 3, 4], DL={'cap_high_new': [0, 1, 2], 'cap_low_new': [0, 1, 2], 'cap_low_exp': [0, 1]}
#     -> CRITICAL ERROR for '十一、公共服务及管理组织': 'ARDLResults' object has no attribute 'rsquared_adj', skipping.
#
# ============================== SOTA ARDL Analysis Summary ==============================
# ### 各行业【长期影响系数 β_long】(kWh/kVA)
# 绿色粗体: **显著**且存在长期协整关系; 橙色粗体: **显著**但无长期协整关系; 灰色: 不显著
# <style type="text/css">
# #T_93ce8_row0_col0, #T_93ce8_row0_col1, #T_93ce8_row0_col2, #T_93ce8_row0_col3, #T_93ce8_row1_col0, #T_93ce8_row1_col1, #T_93ce8_row1_col2, #T_93ce8_row1_col3, #T_93ce8_row2_col0, #T_93ce8_row2_col1, #T_93ce8_row2_col2, #T_93ce8_row2_col3, #T_93ce8_row3_col0, #T_93ce8_row3_col1, #T_93ce8_row3_col2, #T_93ce8_row3_col3, #T_93ce8_row4_col0, #T_93ce8_row4_col1, #T_93ce8_row4_col2, #T_93ce8_row4_col3, #T_93ce8_row5_col0, #T_93ce8_row5_col1, #T_93ce8_row5_col2, #T_93ce8_row5_col3, #T_93ce8_row6_col0, #T_93ce8_row6_col1, #T_93ce8_row6_col2, #T_93ce8_row6_col3, #T_93ce8_row7_col0, #T_93ce8_row7_col1, #T_93ce8_row7_col2, #T_93ce8_row7_col3, #T_93ce8_row8_col0, #T_93ce8_row8_col1, #T_93ce8_row8_col2, #T_93ce8_row8_col3, #T_93ce8_row9_col0, #T_93ce8_row9_col1, #T_93ce8_row9_col2, #T_93ce8_row9_col3, #T_93ce8_row10_col0, #T_93ce8_row10_col1, #T_93ce8_row10_col2, #T_93ce8_row10_col3, #T_93ce8_row11_col0, #T_93ce8_row11_col1, #T_93ce8_row11_col2, #T_93ce8_row11_col3, #T_93ce8_row12_col0, #T_93ce8_row12_col1, #T_93ce8_row12_col2, #T_93ce8_row12_col3, #T_93ce8_row13_col0, #T_93ce8_row13_col1, #T_93ce8_row13_col2, #T_93ce8_row13_col3, #T_93ce8_row14_col0, #T_93ce8_row14_col1, #T_93ce8_row14_col2, #T_93ce8_row14_col3, #T_93ce8_row15_col0, #T_93ce8_row15_col1, #T_93ce8_row15_col2, #T_93ce8_row15_col3, #T_93ce8_row16_col0, #T_93ce8_row16_col1, #T_93ce8_row16_col2, #T_93ce8_row16_col3, #T_93ce8_row17_col0, #T_93ce8_row17_col1, #T_93ce8_row17_col2, #T_93ce8_row17_col3, #T_93ce8_row18_col0, #T_93ce8_row18_col1, #T_93ce8_row18_col2, #T_93ce8_row18_col3, #T_93ce8_row19_col0, #T_93ce8_row19_col1, #T_93ce8_row19_col2, #T_93ce8_row19_col3, #T_93ce8_row20_col0, #T_93ce8_row20_col1, #T_93ce8_row20_col2, #T_93ce8_row20_col3, #T_93ce8_row21_col0, #T_93ce8_row21_col1, #T_93ce8_row21_col2, #T_93ce8_row21_col3, #T_93ce8_row22_col0, #T_93ce8_row22_col1, #T_93ce8_row22_col2, #T_93ce8_row22_col3, #T_93ce8_row23_col0, #T_93ce8_row23_col1, #T_93ce8_row23_col2, #T_93ce8_row23_col3, #T_93ce8_row24_col0, #T_93ce8_row24_col1, #T_93ce8_row24_col2, #T_93ce8_row24_col3, #T_93ce8_row25_col0, #T_93ce8_row25_col1, #T_93ce8_row25_col2, #T_93ce8_row25_col3, #T_93ce8_row26_col0, #T_93ce8_row26_col1, #T_93ce8_row26_col2, #T_93ce8_row26_col3, #T_93ce8_row27_col0, #T_93ce8_row27_col1, #T_93ce8_row27_col2, #T_93ce8_row27_col3, #T_93ce8_row28_col0, #T_93ce8_row28_col1, #T_93ce8_row28_col2, #T_93ce8_row28_col3, #T_93ce8_row29_col0, #T_93ce8_row29_col1, #T_93ce8_row29_col2, #T_93ce8_row29_col3, #T_93ce8_row30_col0, #T_93ce8_row30_col1, #T_93ce8_row30_col2, #T_93ce8_row30_col3, #T_93ce8_row31_col0, #T_93ce8_row31_col1, #T_93ce8_row31_col2, #T_93ce8_row31_col3, #T_93ce8_row32_col0, #T_93ce8_row32_col1, #T_93ce8_row32_col2, #T_93ce8_row32_col3 {
#   color: grey;
# }
# </style>
# <table id="T_93ce8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93ce8_level0_col0" class="col_heading level0 col0" >cap_high_exp</th>
#       <th id="T_93ce8_level0_col1" class="col_heading level0 col1" >cap_high_new</th>
#       <th id="T_93ce8_level0_col2" class="col_heading level0 col2" >cap_low_exp</th>
#       <th id="T_93ce8_level0_col3" class="col_heading level0 col3" >cap_low_new</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >行业分类</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93ce8_level0_row0" class="row_heading level0 row0" >全行业总计</th>
#       <td id="T_93ce8_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_93ce8_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_93ce8_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_93ce8_row0_col3" class="data row0 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row1" class="row_heading level0 row1" >A、全行业用电合计</th>
#       <td id="T_93ce8_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_93ce8_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_93ce8_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_93ce8_row1_col3" class="data row1 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row2" class="row_heading level0 row2" >第一产业</th>
#       <td id="T_93ce8_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_93ce8_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_93ce8_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_93ce8_row2_col3" class="data row2 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row3" class="row_heading level0 row3" >第二产业</th>
#       <td id="T_93ce8_row3_col0" class="data row3 col0" >-</td>
#       <td id="T_93ce8_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_93ce8_row3_col2" class="data row3 col2" >-</td>
#       <td id="T_93ce8_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row4" class="row_heading level0 row4" >第三产业</th>
#       <td id="T_93ce8_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_93ce8_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_93ce8_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_93ce8_row4_col3" class="data row4 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row5" class="row_heading level0 row5" >B、城乡居民生活用电合计</th>
#       <td id="T_93ce8_row5_col0" class="data row5 col0" >-</td>
#       <td id="T_93ce8_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_93ce8_row5_col2" class="data row5 col2" >-</td>
#       <td id="T_93ce8_row5_col3" class="data row5 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row6" class="row_heading level0 row6" >二、工业</th>
#       <td id="T_93ce8_row6_col0" class="data row6 col0" >-</td>
#       <td id="T_93ce8_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_93ce8_row6_col2" class="data row6 col2" >-</td>
#       <td id="T_93ce8_row6_col3" class="data row6 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row7" class="row_heading level0 row7" >（二）制造业</th>
#       <td id="T_93ce8_row7_col0" class="data row7 col0" >-</td>
#       <td id="T_93ce8_row7_col1" class="data row7 col1" >-</td>
#       <td id="T_93ce8_row7_col2" class="data row7 col2" >-</td>
#       <td id="T_93ce8_row7_col3" class="data row7 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row8" class="row_heading level0 row8" >13.石油、煤炭及其他燃料加工业</th>
#       <td id="T_93ce8_row8_col0" class="data row8 col0" >-</td>
#       <td id="T_93ce8_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_93ce8_row8_col2" class="data row8 col2" >-</td>
#       <td id="T_93ce8_row8_col3" class="data row8 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row9" class="row_heading level0 row9" >14.化学原料和化学制品制造业</th>
#       <td id="T_93ce8_row9_col0" class="data row9 col0" >-</td>
#       <td id="T_93ce8_row9_col1" class="data row9 col1" >-</td>
#       <td id="T_93ce8_row9_col2" class="data row9 col2" >-</td>
#       <td id="T_93ce8_row9_col3" class="data row9 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row10" class="row_heading level0 row10" >15.医药制造业</th>
#       <td id="T_93ce8_row10_col0" class="data row10 col0" >-</td>
#       <td id="T_93ce8_row10_col1" class="data row10 col1" >-</td>
#       <td id="T_93ce8_row10_col2" class="data row10 col2" >-</td>
#       <td id="T_93ce8_row10_col3" class="data row10 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row11" class="row_heading level0 row11" >16.化学纤维制造业</th>
#       <td id="T_93ce8_row11_col0" class="data row11 col0" >-</td>
#       <td id="T_93ce8_row11_col1" class="data row11 col1" >-</td>
#       <td id="T_93ce8_row11_col2" class="data row11 col2" >-</td>
#       <td id="T_93ce8_row11_col3" class="data row11 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_93ce8_level0_row12" class="row_heading level0 row12" >17.橡胶和塑料制品业</th>
#       <td id="T_93ce8_row12_col0" class="data row12 col0" >-</td>
#       <td id="T_93ce8_row12_col1" class="data row12 col1" >
# ### 各行业【短期冲击系数 β_short】(当期影响)
# <style type="text/css">
# </style>
# <table id="T_0bc67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bc67_level0_col0" class="col_heading level0 col0" >cap_high_exp</th>
#       <th id="T_0bc67_level0_col1" class="col_heading level0 col1" >cap_high_new</th>
#       <th id="T_0bc67_level0_col2" class="col_heading level0 col2" >cap_low_exp</th>
#       <th id="T_0bc67_level0_col3" class="col_heading level0 col3" >cap_low_new</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >行业分类</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bc67_level0_row0" class="row_heading level0 row0" >全行业总计</th>
#       <td id="T_0bc67_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_0bc67_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_0bc67_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_0bc67_row0_col3" class="data row0 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row1" class="row_heading level0 row1" >A、全行业用电合计</th>
#       <td id="T_0bc67_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_0bc67_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_0bc67_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_0bc67_row1_col3" class="data row1 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row2" class="row_heading level0 row2" >第一产业</th>
#       <td id="T_0bc67_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_0bc67_row2_col1" class="data row2 col1" >-</td>
#       <td id="T_0bc67_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_0bc67_row2_col3" class="data row2 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row3" class="row_heading level0 row3" >第二产业</th>
#       <td id="T_0bc67_row3_col0" class="data row3 col0" >-</td>
#       <td id="T_0bc67_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_0bc67_row3_col2" class="data row3 col2" >-</td>
#       <td id="T_0bc67_row3_col3" class="data row3 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row4" class="row_heading level0 row4" >第三产业</th>
#       <td id="T_0bc67_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_0bc67_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_0bc67_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_0bc67_row4_col3" class="data row4 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row5" class="row_heading level0 row5" >B、城乡居民生活用电合计</th>
#       <td id="T_0bc67_row5_col0" class="data row5 col0" >-</td>
#       <td id="T_0bc67_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_0bc67_row5_col2" class="data row5 col2" >-</td>
#       <td id="T_0bc67_row5_col3" class="data row5 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row6" class="row_heading level0 row6" >二、工业</th>
#       <td id="T_0bc67_row6_col0" class="data row6 col0" >-</td>
#       <td id="T_0bc67_row6_col1" class="data row6 col1" >-</td>
#       <td id="T_0bc67_row6_col2" class="data row6 col2" >-</td>
#       <td id="T_0bc67_row6_col3" class="data row6 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row7" class="row_heading level0 row7" >（二）制造业</th>
#       <td id="T_0bc67_row7_col0" class="data row7 col0" >-</td>
#       <td id="T_0bc67_row7_col1" class="data row7 col1" >-</td>
#       <td id="T_0bc67_row7_col2" class="data row7 col2" >-</td>
#       <td id="T_0bc67_row7_col3" class="data row7 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row8" class="row_heading level0 row8" >13.石油、煤炭及其他燃料加工业</th>
#       <td id="T_0bc67_row8_col0" class="data row8 col0" >-</td>
#       <td id="T_0bc67_row8_col1" class="data row8 col1" >-</td>
#       <td id="T_0bc67_row8_col2" class="data row8 col2" >-</td>
#       <td id="T_0bc67_row8_col3" class="data row8 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row9" class="row_heading level0 row9" >14.化学原料和化学制品制造业</th>
#       <td id="T_0bc67_row9_col0" class="data row9 col0" >-</td>
#       <td id="T_0bc67_row9_col1" class="data row9 col1" >-</td>
#       <td id="T_0bc67_row9_col2" class="data row9 col2" >-</td>
#       <td id="T_0bc67_row9_col3" class="data row9 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row10" class="row_heading level0 row10" >15.医药制造业</th>
#       <td id="T_0bc67_row10_col0" class="data row10 col0" >-</td>
#       <td id="T_0bc67_row10_col1" class="data row10 col1" >-</td>
#       <td id="T_0bc67_row10_col2" class="data row10 col2" >-</td>
#       <td id="T_0bc67_row10_col3" class="data row10 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row11" class="row_heading level0 row11" >16.化学纤维制造业</th>
#       <td id="T_0bc67_row11_col0" class="data row11 col0" >-</td>
#       <td id="T_0bc67_row11_col1" class="data row11 col1" >-</td>
#       <td id="T_0bc67_row11_col2" class="data row11 col2" >-</td>
#       <td id="T_0bc67_row11_col3" class="data row11 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row12" class="row_heading level0 row12" >17.橡胶和塑料制品业</th>
#       <td id="T_0bc67_row12_col0" class="data row12 col0" >-</td>
#       <td id="T_0bc67_row12_col1" class="data row12 col1" >-</td>
#       <td id="T_0bc67_row12_col2" class="data row12 col2" >-</td>
#       <td id="T_0bc67_row12_col3" class="data row12 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row13" class="row_heading level0 row13" >18.非金属矿物制品业</th>
#       <td id="T_0bc67_row13_col0" class="data row13 col0" >-</td>
#       <td id="T_0bc67_row13_col1" class="data row13 col1" >-</td>
#       <td id="T_0bc67_row13_col2" class="data row13 col2" >-</td>
#       <td id="T_0bc67_row13_col3" class="data row13 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row14" class="row_heading level0 row14" >19.黑色金属冶炼和压延加工业</th>
#       <td id="T_0bc67_row14_col0" class="data row14 col0" >-</td>
#       <td id="T_0bc67_row14_col1" class="data row14 col1" >-</td>
#       <td id="T_0bc67_row14_col2" class="data row14 col2" >-</td>
#       <td id="T_0bc67_row14_col3" class="data row14 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row15" class="row_heading level0 row15" >20.有色金属冶炼和压延加工业</th>
#       <td id="T_0bc67_row15_col0" class="data row15 col0" >-</td>
#       <td id="T_0bc67_row15_col1" class="data row15 col1" >-</td>
#       <td id="T_0bc67_row15_col2" class="data row15 col2" >-</td>
#       <td id="T_0bc67_row15_col3" class="data row15 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row16" class="row_heading level0 row16" >21.金属制品业</th>
#       <td id="T_0bc67_row16_col0" class="data row16 col0" >-</td>
#       <td id="T_0bc67_row16_col1" class="data row16 col1" >-</td>
#       <td id="T_0bc67_row16_col2" class="data row16 col2" >-</td>
#       <td id="T_0bc67_row16_col3" class="data row16 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row17" class="row_heading level0 row17" >22.通用设备制造业</th>
#       <td id="T_0bc67_row17_col0" class="data row17 col0" >-</td>
#       <td id="T_0bc67_row17_col1" class="data row17 col1" >-</td>
#       <td id="T_0bc67_row17_col2" class="data row17 col2" >-</td>
#       <td id="T_0bc67_row17_col3" class="data row17 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row18" class="row_heading level0 row18" >23.专用设备制造业</th>
#       <td id="T_0bc67_row18_col0" class="data row18 col0" >-</td>
#       <td id="T_0bc67_row18_col1" class="data row18 col1" >-</td>
#       <td id="T_0bc67_row18_col2" class="data row18 col2" >-</td>
#       <td id="T_0bc67_row18_col3" class="data row18 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_0bc67_level0_row19" class="row_heading level0 row19" >24.汽车制造业</th>
#       <td id="T_0bc67_row19_col0" class="data row19 col0" >-</td>
#       <td id="T_0bc67_row19_col1" class="data row19 col1" >-</td>
#       <td id="T_0bc67_row19_col2" class="data row19 col2" >-</td>
#       <td id="T_0bc67_row19_col3" class="data row19 col3" >-</td>
#     </tr>
#     <tr>
# Full summary report saved to: E:\A智网\业扩分析\业扩ARDL模型\ARDL分析报告_无春节变量版.xlsx
#
# --- State-of-the-Art Analysis Complete ---
